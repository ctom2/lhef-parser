# %% [markdown]
# Import of the methods and classes.

# %%
from lhefparser import *

# %% [markdown]
# Reading the process data.

# %%
p = ReadLHEF('evrecout.dat')

# %% [markdown]
# Printing the number of events in the generated LHEF file.

# %%
print(len(p.events))
# Out:
# 5000

# %% [markdown]
# Printing the number of particles in the event.

# %%
print(p.events[0].nparticles)
# Out:
# 5

# %% [markdown]
# Plotting the mass distribution of masses of 3th and 4th particle participating in the event. The unit parameter is set to keV and the histogram has 100 bins.

# %%
CreateHistogram(p, [3,4], 'M', 'keV', 100)
